# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks=pd.read_csv("songs_normalize.csv")
df_tracks.head()
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre
# ...

# %%
# To check null values

pd.isnull(df_tracks).sum()
# Out:
# artist              0
# song                0
# duration_ms         0
# explicit            0
# year                0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# genre               0
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1997 entries, 0 to 1996
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            1997 non-null   object
#  1   song              1997 non-null   object
#  2   duration_ms       1997 non-null   int64
#  3   explicit          1997 non-null   bool
#  4   year              1997 non-null   int64
#  5   popularity        1997 non-null   int64
#  6   danceability      1997 non-null   float64
#  7   energy            1997 non-null   float64
#  8   key               1997 non-null   int64
#  9   loudness          1997 non-null   float64
#  10  mode              1997 non-null   int64
#  11  speechiness       1997 non-null   float64
#  12  acousticness      1997 non-null   float64
#  13  instrumentalness  1997 non-null   float64
#  14  liveness          1997 non-null   float64
#  15  valence           1997 non-null   float64
# ...

# %%
#sort on the basis of popularity
sorted_df=df_tracks.sort_values('popularity', ascending=False).head(10)
sorted_df
# Out:
#                  artist                  song  duration_ms  explicit  year  \
# 1320  The Neighbourhood       Sweater Weather       240400     False  2013
# 1309          Tom Odell          Another Love       244360      True  2013
# 201              Eminem            Without Me       290320      True  2002
# 1611             WILLOW        Wait a Minute!       196520     False  2015
# 6                Eminem   The Real Slim Shady       284200      True  2000
# 1927      Billie Eilish  lovely (with Khalid)       200185     False  2018
# 1817      Billie Eilish  lovely (with Khalid)       200185     False  2018
# 1510  The Neighbourhood          Daddy Issues       260173     False  2015
# 1707         Ed Sheeran               Perfect       263400     False  2017
# 1996        Post Malone               Circles       215280     False  2019
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
df_tracks.describe().transpose() #Statistics about count, mean, standard Deviation, minimum value.....
# Out:
#                    count           mean           std            min  \
# duration_ms       1997.0  228765.178768  39157.654732  113000.000000
# year              1997.0    2009.478217      5.850180    1998.000000
# popularity        1997.0      59.897346     21.338525       0.000000
# danceability      1997.0       0.667320      0.140361       0.129000
# energy            1997.0       0.720269      0.152770       0.054900
# key               1997.0       5.380571      3.616426       0.000000
# loudness          1997.0      -5.513316      1.934654     -20.514000
# mode              1997.0       0.554331      0.497164       0.000000
# speechiness       1997.0       0.103565      0.096207       0.023200
# acousticness      1997.0       0.128928      0.173347       0.000019
# instrumentalness  1997.0       0.015246      0.087835       0.000000
# liveness          1997.0       0.181105      0.140504       0.021500
# valence           1997.0       0.551707      0.220941       0.038100
# ...

# %%
most_popular=df_tracks.query('popularity>80',inplace = False).sort_values('popularity',ascending=False)
most_popular[:10]
# Out:
#                  artist                  song  duration_ms  explicit  year  \
# 1320  The Neighbourhood       Sweater Weather       240400     False  2013
# 1309          Tom Odell          Another Love       244360      True  2013
# 201              Eminem            Without Me       290320      True  2002
# 6                Eminem   The Real Slim Shady       284200      True  2000
# 1927      Billie Eilish  lovely (with Khalid)       200185     False  2018
# 1817      Billie Eilish  lovely (with Khalid)       200185     False  2018
# 1611             WILLOW        Wait a Minute!       196520     False  2015
# 1225         Bruno Mars  Locked out of Heaven       233478     False  2012
# 1707         Ed Sheeran               Perfect       263400     False  2017
# 1512             Avicii            The Nights       176658     False  2014
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
# TO convert milli seconds into seconds
df_tracks["duration"]= df_tracks["duration_ms"].apply(lambda x: round(x/1000))
df_tracks.drop("duration_ms",inplace=True, axis=1)

# %%
df_tracks.duration.head()
# Out:
# 0    211
# 1    167
# 2    251
# 3    224
# 4    201
# Name: duration, dtype: int64

# %%
#cmap stands for color map, just go to google and search cmap sns
corr_df=df_tracks.drop(["key","mode","explicit"],axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(corr_df,annot=True,fmt=".1g",vmin=-1,vmax=1,center=0,cmap="inferno", linewidths=1, linecolor="Black")
heatmap.set_title("Correlation Heatmap Between Variable")
heatmap.set_xticklabels(heatmap.get_xticklabels(),rotation=90)
# Out:
# [Text(0.5, 0, 'year'),
#  Text(1.5, 0, 'popularity'),
#  Text(2.5, 0, 'danceability'),
#  Text(3.5, 0, 'energy'),
#  Text(4.5, 0, 'loudness'),
#  Text(5.5, 0, 'speechiness'),
#  Text(6.5, 0, 'acousticness'),
#  Text(7.5, 0, 'instrumentalness'),
#  Text(8.5, 0, 'liveness'),
#  Text(9.5, 0, 'valence'),
#  Text(10.5, 0, 'tempo'),
#  Text(11.5, 0, 'duration')]

# %%
sample_df=df_tracks.sample(int(0.004*len(df_tracks)))
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df, y ="loudness",x="energy",color="c").set(title="Loudness Vs Energy Correlation")

# With loudness, Energy is also increasing and we can observe the linear regression line here, which is increasing gradually
# Out:
# [Text(0.5, 1.0, 'Loudness Vs Energy Correlation')]

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="year",data=df_tracks)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>
